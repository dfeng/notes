# %%
import os
rootdir = '.'
for subdir, dirs, files in os.walk(rootdir):
    for f in files:
# Out:
# 202012211355-new-medium.Rmd
# multidimensional-mental-representations-of-natural-objects.md
# 202012101747-grand-theory-of-social-networks.Rmd
# 202007072258-two-cultures.Rmd
# 202102031842-securities-law-and-insurance.Rmd
# knowledge-distillation.md
# 202007091130-bitter-lesson.Rmd
# 202104181206-rotation-dynamics-in-neurons.Rmd
# 202106031419-a-universal-law-of-robustness-via-isoperimetry.Rmd
# 202102111106-the-asymmetry-of-bitcoin.Rmd
# 202006121135-meta-learning.Rmd
# 202007231854-system-1-and-2.Rmd
# 202005221357-overparameterized-regression.Rmd
# ai-for-health.md
# 202005231829-meta-analysis-vs-preregistration.Rmd
# stewardship-of-global-collective-beahvior.md
# 202006191646-on-optimization.Rmd
# kahneman-neurips-perception.md
# 202106202228-explainable-trees.Rmd
# 202012311105-the-perils-of-explainability.Rmd
# 202006161818-debiasing-word-embeddings.Rmd
# objection-detection-for-guis.md
# 202007101113-next-steps-for-deep-learning.Rmd
# 202005191730-pseudo-inverses-and-sgd.Rmd
# ...
